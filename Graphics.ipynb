# %% [markdown]
# # Practical lesson plotting

# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## Define function

# %%
def f(x):
    return (x - 1) ** 2 + 1

# %% [markdown]
# Create some $x$. There are three ways for creating $x$

# %%
x = np.linspace(-10, 10, 100) # 100 points will be created in range (-10, 10)
x
# Out:
# array([-10.        ,  -9.7979798 ,  -9.5959596 ,  -9.39393939,
#         -9.19191919,  -8.98989899,  -8.78787879,  -8.58585859,
#         -8.38383838,  -8.18181818,  -7.97979798,  -7.77777778,
#         -7.57575758,  -7.37373737,  -7.17171717,  -6.96969697,
#         -6.76767677,  -6.56565657,  -6.36363636,  -6.16161616,
#         -5.95959596,  -5.75757576,  -5.55555556,  -5.35353535,
#         -5.15151515,  -4.94949495,  -4.74747475,  -4.54545455,
#         -4.34343434,  -4.14141414,  -3.93939394,  -3.73737374,
#         -3.53535354,  -3.33333333,  -3.13131313,  -2.92929293,
#         -2.72727273,  -2.52525253,  -2.32323232,  -2.12121212,
#         -1.91919192,  -1.71717172,  -1.51515152,  -1.31313131,
#         -1.11111111,  -0.90909091,  -0.70707071,  -0.50505051,
#         -0.3030303 ,  -0.1010101 ,   0.1010101 ,   0.3030303 ,
#          0.50505051,   0.70707071,   0.90909091,   1.11111111,
#          1.31313131,   1.51515152,   1.71717172,   1.91919192,
# ...

# %%
x = np.arange(-10, 10, 0.2) # points will be created in range (-10, 10) with step 0.1
x
# Out:
# array([-1.00000000e+01, -9.80000000e+00, -9.60000000e+00, -9.40000000e+00,
#        -9.20000000e+00, -9.00000000e+00, -8.80000000e+00, -8.60000000e+00,
#        -8.40000000e+00, -8.20000000e+00, -8.00000000e+00, -7.80000000e+00,
#        -7.60000000e+00, -7.40000000e+00, -7.20000000e+00, -7.00000000e+00,
#        -6.80000000e+00, -6.60000000e+00, -6.40000000e+00, -6.20000000e+00,
#        -6.00000000e+00, -5.80000000e+00, -5.60000000e+00, -5.40000000e+00,
#        -5.20000000e+00, -5.00000000e+00, -4.80000000e+00, -4.60000000e+00,
#        -4.40000000e+00, -4.20000000e+00, -4.00000000e+00, -3.80000000e+00,
#        -3.60000000e+00, -3.40000000e+00, -3.20000000e+00, -3.00000000e+00,
#        -2.80000000e+00, -2.60000000e+00, -2.40000000e+00, -2.20000000e+00,
#        -2.00000000e+00, -1.80000000e+00, -1.60000000e+00, -1.40000000e+00,
#        -1.20000000e+00, -1.00000000e+00, -8.00000000e-01, -6.00000000e-01,
# ...

# %% [markdown]
# After creatig $x$ you can determine $y$ just puting into function f

# %%
y = f(x)
y
# Out:
# array([122.  , 117.64, 113.36, 109.16, 105.04, 101.  ,  97.04,  93.16,
#         89.36,  85.64,  82.  ,  78.44,  74.96,  71.56,  68.24,  65.  ,
#         61.84,  58.76,  55.76,  52.84,  50.  ,  47.24,  44.56,  41.96,
#         39.44,  37.  ,  34.64,  32.36,  30.16,  28.04,  26.  ,  24.04,
#         22.16,  20.36,  18.64,  17.  ,  15.44,  13.96,  12.56,  11.24,
#         10.  ,   8.84,   7.76,   6.76,   5.84,   5.  ,   4.24,   3.56,
#          2.96,   2.44,   2.  ,   1.64,   1.36,   1.16,   1.04,   1.  ,
#          1.04,   1.16,   1.36,   1.64,   2.  ,   2.44,   2.96,   3.56,
#          4.24,   5.  ,   5.84,   6.76,   7.76,   8.84,  10.  ,  11.24,
#         12.56,  13.96,  15.44,  17.  ,  18.64,  20.36,  22.16,  24.04,
#         26.  ,  28.04,  30.16,  32.36,  34.64,  37.  ,  39.44,  41.96,
#         44.56,  47.24,  50.  ,  52.84,  55.76,  58.76,  61.84,  65.  ,
#         68.24,  71.56,  74.96,  78.44])

# %% [markdown]
# ## Plotting

# %%
plt.plot(x, y)

# %%
plt.plot(x, y, marker='o', color = 'r') # you can change stile, marker, color etc.

# %%
plt.plot(x, y, linestyle='-.', color = 'g')

# %% [markdown]
# Another way for plotting

# %%
x = np.linspace(-10, 10, 10)
y = f(x)
plt.plot(x, y, 'g')

# %%
from sklearn.datasets import load_iris

data = load_iris()

# %%
data['feature_names']
# Out:
# ['sepal length (cm)',
#  'sepal width (cm)',
#  'petal length (cm)',
#  'petal width (cm)']

# %%
x = data['data']

# %%
y = data['target']

# %%
plt.scatter(x[:,0], x[:,1], c=y)

# %%
x = np.linspace(-10, 10, 50)
y = f(x)
plt.scatter(x,y) #plotting just point

# %% [markdown]
# You can plot different functions together on one figure.

# %%
def func1(x):
    return (x - 1) ** 2 + 1

def func2(x):
    return 3 * x - 4

def func3(x):
    return x ** 3 - 2

x = np.linspace(-5, 5, 100)

y1 = func1(x)
y2 = func2(x)
y3 = func3(x)

# %%
plt.plot(x, y1, 'b-.')
plt.plot(x, y2, 'g--')
plt.plot(x, y3, 'r:')
plt.title('Functions')
plt.legend(('quadratic', 'linear' , 'cubic'))
plt.xlabel('x-axis')
plt.ylabel('y-axis')
# Out:
# Text(0,0.5,'y-axis')

# %% [markdown]
# Plotting 3D graphics

# %%
from mpl_toolkits.mplot3d import Axes3D
fig = plt.figure()
ax = fig.gca(projection='3d') 

X = np.arange(-5, 5, 0.25)
Y = np.arange(-5, 5, 0.25)
X, Y = np.meshgrid(X, Y)
Z = np.cos(np.sqrt(X**2 + Y**2))

surf = ax.plot_surface(X, Y, Z)
ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_zlabel('Z')
plt.show()

# %% [markdown]
# ## Task #1. Plot function
# $y(x) = sin(5x) + sin(x)$ $x$ belongs to range [-5, 2]

# %% [markdown]
# ## Basic Errorbars

# %%
np.random.randn(10)
# Out:
# array([ 0.10033431,  0.53208874,  0.69226725,  0.5571436 , -0.95142404,
#        -1.39856895, -0.37464805, -0.1742634 , -0.43349222,  1.65054259])

# %%
np.random.randn(50)

# %%
x = np.linspace(0, 10, 50)
dy = 0.1
noise = dy * np.random.randn(50)
y = np.sin(x) + noise

plt.errorbar(x, y, yerr=dy, fmt='.k');

# %%
plt.errorbar(x, y, yerr=dy, fmt='o', color='black',
             ecolor='lightgray', elinewidth=3, capsize=0)
# Out:
# <ErrorbarContainer object of 3 artists>

# %% [markdown]
# ## Visualizing a Three-Dimensional function

# %%
def f(x, y):
    return np.sin(x) ** 10 + np.cos(10 + y * x) * np.cos(x)

# %%
x = np.linspace(0, 5, 50)
y = np.linspace(0, 5, 40)

X, Y = np.meshgrid(x, y)
Z = f(X, Y)

# %%
plt.contour(X, Y, Z, colors='black');

# %%
plt.contour(X, Y, Z, 20, cmap='RdGy');

# %%
plt.contourf(X, Y, Z, 20, cmap='RdGy')
plt.colorbar();

# %% [markdown]
# ## Task #2 Plot 3D function
# $y = 2 * sin(xy) + cos(xy)$, where $x$ and $y$ belongs to range [-5, 5] And plot it.

# %% [markdown]
# # Histograms and Density

# %%
data = np.random.randn(100)
data
# Out:
# array([ 0.01829968, -0.68021578, -0.54107918,  1.65197261,  1.15145118,
#         0.30500054, -0.28821723, -1.12715038,  0.47600268, -1.11243185,
#        -0.5691168 , -0.39994505,  0.64931885,  1.57571809, -0.52771442,
#         1.4490424 , -0.98465046, -0.20635089,  0.98518726, -0.52936496,
#         1.62663163, -0.62970806,  1.40639316,  0.15667241,  1.44285799,
#         0.50734873,  1.7322676 , -0.05557501,  0.13905934,  0.89421328,
#         0.18457751, -1.13515634,  0.76448425,  0.13435541, -1.92707213,
#        -0.93255445,  1.7605274 ,  0.45516743, -0.77052009,  0.54504294,
#         2.59688869,  0.11092356,  0.6939278 , -0.19599798, -1.53495714,
#         2.03758626,  0.79333632, -1.06242943,  0.75946509,  0.57063935,
#        -2.81119936,  1.71246353, -1.26907309, -0.50529811, -0.69402558,
#         0.08450528, -0.32923114, -1.95471852,  0.4352308 , -0.79079279,
#         0.13774444, -1.32788953, -0.47942218, -0.67335824,  0.40237226,
# ...

# %%
plt.scatter(data, np.zeros(len(data)))

# %%
plt.hist(data, bins=10)
# Out:
# (array([ 1.,  0.,  2.,  4., 12., 25., 24., 18., 11.,  3.]),
#  array([-4.22230936, -3.54038956, -2.85846975, -2.17654995, -1.49463014,
#         -0.81271034, -0.13079053,  0.55112927,  1.23304908,  1.91496889,
#          2.59688869]),
#  <a list of 10 Patch objects>)

# %%
plt.hist(data, bins=30, normed=True, alpha=0.5,
         histtype='stepfilled', color='steelblue',
         edgecolor='none');
# Out:
# /home/vasily/.virtualenvs/keras/lib/python3.6/site-packages/matplotlib/axes/_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
x1 = np.random.normal(0, 0.8, 1000)
x2 = np.random.normal(-2, 1, 1000)
x3 = np.random.normal(3, 2, 1000)

kwargs = dict(histtype='stepfilled', alpha=0.3, normed=True, bins=40)

plt.hist(x1, **kwargs)
plt.hist(x2, **kwargs)
plt.hist(x3, **kwargs);
# Out:
# /home/vasily/.virtualenvs/keras/lib/python3.6/site-packages/matplotlib/axes/_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %% [markdown]
# # Customizing Plot Legends

# %%
x = np.linspace(0, 10, 1000)
plt.plot(x, np.sin(x), '-b', label='Sine')
plt.plot(x, np.cos(x), '--r', label='Cosine')
plt.axis('equal')
plt.legend()

# %%
x = np.linspace(0, 10, 1000)
fig, ax = plt.subplots()
ax.plot(x, np.sin(x), '-b', label='Sine')
ax.plot(x, np.cos(x), '--r', label='Cosine')
ax.axis('equal')
leg = ax.legend();

# %%
ax.legend(loc='upper left', frameon=False)
fig

# %%
ax.legend(frameon=False, loc='lower center', ncol=2)
fig

# %%
ax.legend(fancybox=True, framealpha=1, shadow=True, borderpad=1)
fig

# %% [markdown]
# # Task #3
# Plot two function $y1 = x^2$ and $y2 = cos(x) \times sin(x)$
# Sign the, in legends and use different colors for them.

# %% [markdown]
# ## Customizing Colorbars

# %%
x = np.linspace(0, 10, 1000)
I = np.sin(x) * np.cos(x[:, np.newaxis])

plt.imshow(I, cmap='gray')
plt.colorbar();

# %%
plt.imshow(I, cmap='autumn')
plt.colorbar();

# %%
plt.imshow(I, cmap='brg')
plt.colorbar();

# %%
plt.imshow(I, cmap='cool')
plt.colorbar();

# %% [markdown]
# ## Multiple Subplots

# %%
for i in range(1, 7):
    plt.subplot(2, 3, i)
    plt.text(0.5, 0.5, str((2, 3, i)),
             fontsize=18, ha='center')

# %%
x = np.linspace(-2,2,100)
plt.subplot(2,2,1)
plt.plot(x, np.sin(x))
plt.subplot(2,2,2)
plt.plot(x, np.cos(x))
plt.subplot(2,2,3)
plt.plot(x, x)
plt.subplot(2,2,4)
plt.plot(x, x ** 2)

# %% [markdown]
# ## Task #4
# Plot graphics for $y = x$, $y = x^2$, $y = x^3$, $y = x^4$, $y = x^5$, $y = x^6$ in different subplots.
